# %%
##se llaman librerias
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import sys

# %%
##se leen datos, se crea grafica con mathplotlib y se guarda en el disco
file="resultados"
data_img=np.loadtxt(file)
plt.plot (data_img)
plt.savefig('frecuencias absoluta pendietes.png')

# %%
##se leen datos, se crea grafica con mathplotlib y se guarda en el disco
file="resultados"
data_img=np.loadtxt(file)
plt.hist (data_img)
plt.savefig('histograma.png')

# %%
##se leen datos, se crea grafica con mathplotlib y se guarda en el disco
file="resultados"
data_img=np.loadtxt(file)
plt.plot (*data_img)
plt.savefig('frecuencia_pendientes.png')

# %%
##se leen datos y se guardan en 2 arreglos
file="resultados"
data_img=np.loadtxt(file)
a = data_img[:,0]
b = data_img[:,1]
x = np.linspace(-5,5,100)

# %%
##Se grafican un rango de -5 a 5 como pendiente y eje respectivamente
for i in range (1,1000):

    plt.plot(x, a[i*10]*x+b[i*10])

# %%
##Se grafican un rango de -5 a 5 como pendiente y eje respectivamente y se guardan en diferentes archivos
res="resultados"
name=res#
for i in range (1,1001):
    file=name[i]
    plt.plot(x, a[i*10]*x+b[i*10])
    plt.savefig(file+'.png')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-635819c10c28> in <module>()
#       2 name=res#
#       3 for i in range (1,1001):
# ----> 4     file=name[i]
#       5     plt.plot(x, a[i*10]*x+b[i*10])
#       6     plt.savefig(file+'.png')
#
# IndexError: string index out of range
